# %% [markdown]
# <a href="https://colab.research.google.com/github/iketimkov/python/blob/main/project_euler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
print('Hello World')
# Out:
# Hello World
